# %%
import pixiedust

# %% [markdown]
# # Enable the Spark Progress Monitor

# %%
pixiedust.enableJobMonitor()
# Out:
# Succesfully enabled Spark Job Progress Monitor

# %% [markdown]
# # Sample Data

# %%
pixiedust.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
# ...

# %% [markdown]
# ## Data from anywhere

# %%
#home_df = pixiedust.sampleData(6)

# %%
#home_df = pixiedust.sampleData("https://openobjectstore.mybluemix.net/misc/milliondollarhomes.csv")

# %% [markdown]
# ## Spark DataFrame

# %%
home_df = pixiedust.sampleData("file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv")
# Out:
# Creating pySpark DataFrame for 'file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv'

# %% [markdown]
# ## Pandas DataFrame

# %%
#home_df = pixiedust.sampleData(6, forcePandas = True)
home_df = pixiedust.sampleData("file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv", forcePandas = True)
home_df.head()
# Out:
# Creating pandas DataFrame for 'file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///Users/margriet/cdsdev/notebookdev/pixiedust-demo/data/milliondollarhomes.csv'
#                PROPERTY TYPE               ADDRESS       CITY STATE   ZIP  \
# 0  Single Family Residential     4 Newbury Road Rd    Windham    NH  3087
# 1  Single Family Residential        25 Marshall Rd  Wellesley    MA  2482
# 2  Single Family Residential        15 E Meadow Ln  Middleton    MA  1949
# 3                Condo/Co-op  983 Memorial Dr #302  Cambridge    MA  2138
# 4                Condo/Co-op   1 Franklin St Ph 2E     Boston    MA  2110
#
#      PRICE  BEDS  BATHS        LOCATION     SQFT  LOT SIZE  YEAR BUILT  \
# 0  2450000   5.0    7.5         Windham  13461.0  139392.0      2008.0
# 1  1909847   5.0    4.5       Wellesley   4900.0   12228.0      2016.0
# ...

# %%
display(home_df)

# %%
display(home_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigureba7ccb66" class="pd_save" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(global) {
#   function now() {
#     return new Date();
#   }
#
#   var force = true;
#
#   if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#     window._bokeh_onload_callbacks = [];
#     window._bokeh_is_loading = undefined;
#   }
#
#
#
# ...
